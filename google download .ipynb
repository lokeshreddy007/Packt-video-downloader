# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
os.chdir("/content/drive/My Drive/Packt/RESTful Web API Design with Node.js 12 By Florian Goto")

# !wget -c 'https://d1ft11egbn8l.cloudfront.net/RESTful%20Web%20API%20Design%20with%20Node%20js%2012/Package/videos/video1_6.mp4?Expires=1604171383&Policy=__&Signature=F827ZqbObv55iav1pG1DNxk545DzJUZ54sl3DtPZ9N2RJKuM9Uw796BPp0mt6GfbrBKtPA~O93za~T5NYn3zWzNnIqj9z7u8P4mQZNTrrbjYWwFtR7i9-EwcplTubmW1zxYUZhtweYGE3zNhCQ9BT5BL~j~atafll1sQ77KhOc8_&Key-Pair-Id=APKAJTJLPJQL5PVZ47FA' -O video1_6.mp4 --no-check-certificate

# %%
import os
os.chdir("/content/drive/My Drive/website")

! wget \
     --recursive \
     --no-clobber \
     --page-requisites \
     --html-extension \
     --convert-links \
     --restrict-file-names=windows \
     --domains evilx.su \
     --no-parent \
         https://evilx.su/
